# %%
# Cognifyz Technologies Internship
## Level 1 - Task 3: Price Range Distribution

# %%
# 1. Import libraries
import pandas as pd

# %%
# 2. Load the dataset
df = pd.read_csv("C:\\Users\\sksri\\OneDrive\\Documents\\Cognifyz\\Dataset .csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df["Price range"].head()
# Out:
# 0    3
# 1    3
# 2    4
# 3    4
# 4    4
# Name: Price range, dtype: int64

# %%
df["Price range"].unique()
# Out:
# array([3, 4, 2, 1])

# %%
df["Price range"].value_counts().sort_index()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
# 3. Calculate percentages
price_range_percentage = (price_range_counts / len(df)) * 100
price_range_percentage
# Out:
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: count, dtype: float64

# %%
# 4. Visualization
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.bar(price_range_counts.index, price_range_counts.values)

plt.title("Distribution of Restaurants by Price Range")
plt.xlabel("Price Range")
plt.ylabel("Number of Restaurants")

plt.show()

# %%
## Conclusion

#Price Range 1 has the highest number of restaurants, with 4,444 restaurants, representing 46.53% of the total restaurants in the dataset.
#Price Range 2 is the second most common category, with 3,113 restaurants (32.59%), followed by Price Range 3 with 1,408 restaurants (14.74%).
#Price Range 4 has the lowest number of restaurants, with 586 restaurants, representing 6.14% of the total restaurants.
#Overall, the distribution shows that lower-priced restaurants (Price Ranges 1 and 2) are more common in the dataset.
