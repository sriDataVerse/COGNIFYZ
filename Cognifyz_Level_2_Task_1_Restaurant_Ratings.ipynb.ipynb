# %%
# Cognifyz Technologies Internship
## Level 2 - Task 1: Restaurant Ratings

# %%
# 1. Import libraries
import pandas as pd

# %%
# 2. Load the dataset
df = pd.read_csv("C:\\Users\\sksri\\OneDrive\\Documents\\Cognifyz\\Dataset .csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# 3. Check the Aggregate Rating column
df["Aggregate rating"].describe()
# Out:
# count    9551.000000
# mean        2.666370
# std         1.516378
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate rating, dtype: float64

# %%
df["Aggregate rating"].value_counts().head(10)
# Out:
# Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# Name: count, dtype: int64

# %%
# 4. Visualization
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df["Aggregate rating"], bins=10)

plt.title("Distribution of Aggregate Ratings")
plt.xlabel("Aggregate Rating")
plt.ylabel("Number of Restaurants")

plt.show()

# %%
# 5. Calculate Average Votes
average_votes = df["Votes"].mean()
print("Average Votes:", average_votes)
# Out:
# Average Votes: 156.909747670401

# %%
df["Votes"].describe()
# Out:
# count     9551.000000
# mean       156.909748
# std        430.169145
# min          0.000000
# 25%          5.000000
# 50%         31.000000
# 75%        131.000000
# max      10934.000000
# Name: Votes, dtype: float64

# %%
## Conclusion

#The distribution of aggregate ratings shows that restaurant ratings range from 0.0 to 4.9, with an average rating of 2.67.
#he most common rating observed in the dataset is 0.0, indicating that a significant number of restaurants have not received ratings or have very low ratings.
#The average number of votes received by restaurants is 156.91. However, the median number of votes is only 31, which suggests that a small number of highly popular restaurants receive a very large number of votes compared to the majority of restaurants.
#Overall, the dataset shows considerable variation in both restaurant ratings and customer engagement levels.
